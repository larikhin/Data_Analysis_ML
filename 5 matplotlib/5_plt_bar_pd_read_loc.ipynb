# %%
# подключение библиотек
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# %%
# чтение данных
df = pd.read_csv("FlightDelays_small_no_ID.csv")
df
# Out:
#        Year  Month  DayofMonth  DayOfWeek Carrier OriginAirport DestAirport  \
# 0      2013     10          30          3      UA           EWR         BOS
# 1      2013      7          27          6      AS           SFO         SEA
# 2      2013      6           8          6      WN           HOU         RDU
# 3      2013      4           3          3      UA           DEN         PIT
# 4      2013      7          26          5      EV           EWR         DTW
# ...     ...    ...         ...        ...     ...           ...         ...
# 54383  2013      8          26          1      WN           ORF         BNA
# 54384  2013      4          24          3      YV           SAT         PHX
# 54385  2013     10          20          7      DL           SFO         MSP
# 54386  2013      7          18          4      UA           SFO         IAH
# 54387  2013     10          21          1      EV           IAH         MEM
#
# ...

# %%
# Отбор данных по перевозчику UA и группировка по месяцу
temp = df.loc[df['Carrier'] == 'UA'].groupby(['Month']).count()
temp
# Out:
#        Year  DayofMonth  DayOfWeek  Carrier  OriginAirport  DestAirport  \
# Month
# 4       778         778        778      778            778          778
# 5       779         779        779      779            779          779
# 6       837         837        837      837            837          837
# 7       869         869        869      869            869          869
# 8       826         826        826      826            826          826
# 9       755         755        755      755            755          755
# 10      816         816        816      816            816          816
#
#        CRSDepTime  DepDelay  DepDel15  CRSArrTime  ArrDelay  ArrDel15  \
# Month
# 4             778       766       766         778       765       778
# 5             779       774       774         779       773       779
# 6             837       825       825         837       825       837
# 7             869       857       857         869       856       869
# ...

# %%
# Отделяем данные о количестве совершенных вылетов
FL = list(temp['Year']) 
FL
# Out:
# [778, 779, 837, 869, 826, 755, 816]

# %%
# Создаем подписи для оси Х

# как в примере: хардкодим
x = ['Апрель', 'Май', 'Июнь', 'Июль', 'Август', 'Сентябрь', 'Октябрь']
x_pos = [i for i,v in enumerate(x)]
# как можно: присвоить список индексов списку
x_pos = list(temp.index)
x_pos
plt.bar(x_pos, FL, color='blue', width=0.5)
plt.xlabel("Месяц")
plt.ylabel("Количество совершенных рейсов")

plt.xticks(x_pos, x)

plt.show()

# %%
x_pos
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
[i for i,v in enumerate(x)]
# Out:
# [0, 1, 2, 3, 4, 5, 6]
